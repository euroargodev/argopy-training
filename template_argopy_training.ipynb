# %% [markdown]
# ![Euro-Argo-ONE.png](attachment:59b1e9bb-5f85-43e0-bf3b-076c9dcfabc1.png)
# # Argopy Training - Sept 22<sup>th</sup> 2025
# <hr>
#
# ## Notebook Title :
# ### Author contact :

# %%
import argopy
argopy.show_versions()
# Out:
# SYSTEM
# ------
# commit: None
# python: 3.11.13 | packaged by conda-forge | (main, Jun  4 2025, 14:48:23) [GCC 13.3.0]
# python-bits: 64
# OS: Linux
# OS-release: 6.8.0-65-generic
# machine: x86_64
# processor: x86_64
# byteorder: little
# LC_ALL: None
# LANG: fr_FR.UTF-8
# LOCALE: fr_FR.UTF-8
# libhdf5: 1.14.2
# libnetcdf: 4.9.4-development
#
# INSTALLED VERSIONS: CORE
# ------------------------
# aiohttp     : 3.12.15
# argopy      : 1.3.0
# decorator   : 5.2.1
# erddapy     : 2.2.4
# fsspec      : 2025.7.0
# h5netcdf    : 1.6.4
# netCDF4     : 1.7.2
# packaging   : 25.0
# requests    : 2.32.5
# scipy       : 1.16.1
# toolz       : 1.0.0
# xarray      : 2025.8.0
#
# INSTALLED VERSIONS: EXT.UTIL
# ----------------------------
# gsw         : -
# tqdm        : -
#
# INSTALLED VERSIONS: EXT.FILES
# -----------------------------
# boto3       : -
# kerchunk    : -
# numcodecs   : -
# s3fs        : -
# zarr        : -
#
# INSTALLED VERSIONS: EXT.PERF
# ----------------------------
# ...
